# %%
import glob
from PIL import Image
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid

# %%
image_data = []
for filename in ['ts_pred_final_PNL_SS.eps', 'for_cor_PNL_SS.eps']:
    im = Image.open(filename)
    image_data.append(im)

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 1, figsize=(30., 30.))

for i, filename in enumerate(['math_prop_cor_PNL_SS.jpg', 'line_plot_PNL_SS.jpg']):
    im = Image.open(filename)
    axs[i].imshow(im)
    axs[i].set_frame_on(False)
    axs[i].set_xticklabels([])
    axs[i].set_yticklabels([])
    axs[i].tick_params(length=0)
    axs[i].text(-0.01, 0.9, f'({chr(97+i)})', transform=axs[i].transAxes,
                size=30, weight='bold')

plt.subplots_adjust(hspace=0.01)
#plt.savefig('combine2.eps', format='eps', dpi=1000, bbox_inches='tight')
#plt.savefig('combine2.jpg', format='jpg', dpi=1000, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(30., 30.))

for i, filename in enumerate(['ts_pred_final_PNL_SS.jpg', 'for_cor_PNL_SS.jpg']):
    im = Image.open(filename)
    axs[i].imshow(im)
    axs[i].set_frame_on(False)
    axs[i].set_xticklabels([])
    axs[i].set_yticklabels([])
    axs[i].tick_params(length=0)
    axs[i].text(-0.01, 1, f'({chr(97+i)})', transform=axs[i].transAxes,
                size=30, weight='bold')

plt.subplots_adjust(wspace=0.01)
plt.savefig('combine1.eps', format='eps', dpi=1000, bbox_inches='tight')
#plt.savefig('combine1.jpg', format='jpg', dpi=1000, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 6
#       3 fig, axs = plt.subplots(1, 2, figsize=(30., 30.))
#       5 for i, filename in enumerate(['ts_pred_final_PNL_SS.jpg', 'for_cor_PNL_SS.jpg']):
# ----> 6     im = Image.open(filename)
#       7     axs[i].imshow(im)
#       8     axs[i].set_frame_on(False)
#
# File ~/anaconda3/envs/pnlss/lib/python3.10/site-packages/PIL/Image.py:3277, in open(fp, mode, formats)
#    3274     filename = os.path.realpath(os.fspath(fp))
#    3276 if filename:
# -> 3277     fp = builtins.open(filename, "rb")
#    3278     exclusive_fp = True
#    3280 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/home_carnot/hideaki/lab/christian/240827_reproducibility/dysts/benchmarks/ts_pred_final_PNL_SS.jpg'
